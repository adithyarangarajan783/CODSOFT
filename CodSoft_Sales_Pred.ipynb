# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings("ignore")

print ('All modules ready')
# Out:
# All modules ready

# %%
df = pd.read_csv("/content/car_purchasing.csv",encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
df.drop(columns = ['customer name', 'customer e-mail', 'country'], inplace = True)
df.head()
# Out:
#    gender        age  annual Salary  credit card debt    net worth  \
# 0       0  41.851720    62812.09301      11609.380910  238961.2505
# 1       0  40.870623    66646.89292       9572.957136  530973.9078
# 2       1  43.152897    53798.55112      11160.355060  638467.1773
# 3       1  58.271369    79370.03798      14426.164850  548599.0524
# 4       1  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.describe()
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
X = df.drop ("car purchase amount", axis = 1)
X.head()
# Out:
#    gender        age  annual Salary  credit card debt    net worth
# 0       0  41.851720    62812.09301      11609.380910  238961.2505
# 1       0  40.870623    66646.89292       9572.957136  530973.9078
# 2       1  43.152897    53798.55112      11160.355060  638467.1773
# 3       1  58.271369    79370.03798      14426.164850  548599.0524
# 4       1  57.313749    59729.15130       5358.712177  560304.0671

# %%
y = df['car purchase amount']
y.head()
# Out:
# 0    35321.45877
# 1    45115.52566
# 2    42925.70921
# 3    67422.36313
# 4    55915.46248
# Name: car purchase amount, dtype: float64

# %%
Scaler = MinMaxScaler()
X = Scaler.fit_transform(X)
y = Scaler.fit_transform(y.values.reshape(-1,1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_train.shape)
# Out:
# (400, 5)
# (100, 5)
# (400, 1)
# (400, 1)

# %%
model = Sequential([
    Dense(16, activation ='relu', input_dim = 5),
    Dense(16, activation = 'relu'),
    Dense(1, activation = 'linear')
])

model.compile(optimizer= 'adam', loss = 'mean_squared_error', metrics = ['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                96
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 385 (1.50 KB)
# Trainable params: 385 (1.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs =50, validation_split= 0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 24ms/step - loss: 0.2541 - mean_absolute_error: 0.4731 - val_loss: 0.1839 - val_mean_absolute_error: 0.3898
# Epoch 2/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1232 - mean_absolute_error: 0.3159 - val_loss: 0.0826 - val_mean_absolute_error: 0.2436
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0503 - mean_absolute_error: 0.1860 - val_loss: 0.0329 - val_mean_absolute_error: 0.1406
# Epoch 4/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0212 - mean_absolute_error: 0.1138 - val_loss: 0.0182 - val_mean_absolute_error: 0.1086
# Epoch 5/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0159 - mean_absolute_error: 0.1001 - val_loss: 0.0159 - val_mean_absolute_error: 0.1042
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - mean_absolute_error: 0.0947 - val_loss: 0.0141 - val_mean_absolute_error: 0.0992
# Epoch 7/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0124 - mean_absolute_error: 0.0866 - val_loss: 0.0129 - val_mean_absolute_error: 0.0943
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mean_absolute_error: 0.0822 - val_loss: 0.0122 - val_mean_absolute_error: 0.0912
# Epoch 9/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0106 - mean_absolute_error: 0.0795 - val_loss: 0.0114 - val_mean_absolute_error: 0.0883
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0097 - mean_absolute_error: 0.0762 - val_loss: 0.0104 - val_mean_absolute_error: 0.0854
# Epoch 11/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - mean_absolute_error: 0.0727 - val_loss: 0.0096 - val_mean_absolute_error: 0.0819
# Epoch 12/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0081 - mean_absolute_error: 0.0697 - val_loss: 0.0089 - val_mean_absolute_error: 0.0782
# Epoch 13/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0663 - val_loss: 0.0081 - val_mean_absolute_error: 0.0747
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0630 - val_loss: 0.0076 - val_mean_absolute_error: 0.0713
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0601 - val_loss: 0.0070 - val_mean_absolute_error: 0.0682
# Epoch 16/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_absolute_error: 0.0574 - val_loss: 0.0066 - val_mean_absolute_error: 0.0654
# Epoch 17/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0052 - mean_absolute_error: 0.0550 - val_loss: 0.0062 - val_mean_absolute_error: 0.0631
# Epoch 18/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_absolute_error: 0.0530 - val_loss: 0.0059 - val_mean_absolute_error: 0.0608
# Epoch 19/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_absolute_error: 0.0512 - val_loss: 0.0054 - val_mean_absolute_error: 0.0584
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_absolute_error: 0.0490 - val_loss: 0.0052 - val_mean_absolute_error: 0.0566
# Epoch 21/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_absolute_error: 0.0473 - val_loss: 0.0048 - val_mean_absolute_error: 0.0543
# Epoch 22/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0037 - mean_absolute_error: 0.0453 - val_loss: 0.0046 - val_mean_absolute_error: 0.0531
# Epoch 23/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_absolute_error: 0.0442 - val_loss: 0.0045 - val_mean_absolute_error: 0.0518
# Epoch 24/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0425 - val_loss: 0.0041 - val_mean_absolute_error: 0.0495
# Epoch 25/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_absolute_error: 0.0409 - val_loss: 0.0040 - val_mean_absolute_error: 0.0487
# Epoch 26/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_absolute_error: 0.0398 - val_loss: 0.0038 - val_mean_absolute_error: 0.0469
# Epoch 27/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_absolute_error: 0.0384 - val_loss: 0.0037 - val_mean_absolute_error: 0.0461
# Epoch 28/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - mean_absolute_error: 0.0372 - val_loss: 0.0035 - val_mean_absolute_error: 0.0449
# Epoch 29/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0025 - mean_absolute_error: 0.0362 - val_loss: 0.0033 - val_mean_absolute_error: 0.0436
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - mean_absolute_error: 0.0352 - val_loss: 0.0032 - val_mean_absolute_error: 0.0424
# Epoch 31/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - mean_absolute_error: 0.0343 - val_loss: 0.0031 - val_mean_absolute_error: 0.0418
# Epoch 32/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0022 - mean_absolute_error: 0.0333 - val_loss: 0.0029 - val_mean_absolute_error: 0.0398
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0326 - val_loss: 0.0029 - val_mean_absolute_error: 0.0401
# Epoch 34/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - mean_absolute_error: 0.0316 - val_loss: 0.0027 - val_mean_absolute_error: 0.0388
# Epoch 35/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0307 - val_loss: 0.0027 - val_mean_absolute_error: 0.0390
# Epoch 36/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0019 - mean_absolute_error: 0.0302 - val_loss: 0.0025 - val_mean_absolute_error: 0.0373
# Epoch 37/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0295 - val_loss: 0.0025 - val_mean_absolute_error: 0.0373
# Epoch 38/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0288 - val_loss: 0.0024 - val_mean_absolute_error: 0.0366
# Epoch 39/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0282 - val_loss: 0.0024 - val_mean_absolute_error: 0.0365
# Epoch 40/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0016 - mean_absolute_error: 0.0278 - val_loss: 0.0022 - val_mean_absolute_error: 0.0352
# Epoch 41/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0270 - val_loss: 0.0022 - val_mean_absolute_error: 0.0348
# Epoch 42/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0266 - val_loss: 0.0021 - val_mean_absolute_error: 0.0345
# Epoch 43/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0014 - mean_absolute_error: 0.0261 - val_loss: 0.0020 - val_mean_absolute_error: 0.0338
# Epoch 44/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0014 - mean_absolute_error: 0.0257 - val_loss: 0.0020 - val_mean_absolute_error: 0.0335
# Epoch 45/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0253 - val_loss: 0.0019 - val_mean_absolute_error: 0.0326
# Epoch 46/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0250 - val_loss: 0.0018 - val_mean_absolute_error: 0.0322
# Epoch 47/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0245 - val_loss: 0.0018 - val_mean_absolute_error: 0.0316
# Epoch 48/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0012 - mean_absolute_error: 0.0240 - val_loss: 0.0018 - val_mean_absolute_error: 0.0317
# Epoch 49/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0236 - val_loss: 0.0017 - val_mean_absolute_error: 0.0305
# Epoch 50/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0235 - val_loss: 0.0017 - val_mean_absolute_error: 0.0304

# %%
# training accuracy and loss
acc = history.history['mean_absolute_error']
loss = history.history['loss']


#validation accuracy and loss
v_acc = history.history['val_mean_absolute_error']
v_loss = history.history['val_loss']


#index of lowest v_loss
ind_vloss = np.argmin(v_loss)
lowest_vloss = v_loss[ind_vloss]


#index of highest v_acc
ind_vacc = np.argmax(v_acc)
heighest_vacc = v_acc[ind_vacc]


#number of epochs
epochs = [i +1 for i in range(len(acc))]

#set labels
loss_l = f'Best epoch= {str(ind_vloss +1)}'
acc_l= f'Best epoch = {str(ind_vacc +1)}'


#trainig History visualization
plt.figure(figsize= (20,8))
plt.style.use('fivethirtyeight')

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'r', label = 'Trainig loss')
plt.plot(epochs, v_loss, 'g', label = 'Validation loss')
plt.scatter(ind_vloss +1, lowest_vloss, s = 100, c= 'b', label = loss_l)
plt. title('Loss: Trainig vs Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()


plt.subplot(1,2,2)
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
plt.plot(epochs, v_acc, 'g', label = 'Validation Accuracy')
plt.scatter(ind_vacc+1, heighest_vacc, s = 100, c = 'b', label = acc_l)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
y_pred  = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9510530096442493
